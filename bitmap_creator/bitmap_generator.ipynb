# %% [markdown]
# # Bitmap Image Generator
# Create black & white bitmap images with customizable patterns and dithering algorithms.

# %%
from app import setup_app
from IPython.display import display
# Run the app
app = setup_app()
display(app)
