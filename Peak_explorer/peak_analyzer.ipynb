# %% [markdown]
# # Peak Analyzer - Photoluminescence Analysis
#
# Interactive application for analyzing photoluminescence data with peak detection and fitting.

# %%
from gui_layouts import PLAnalysisApp

app = PLAnalysisApp()
app.display_app()
# Out:
# [13:58:14.952] [APP] Initializing PLAnalysisApp
# [13:58:14.952] [H5] Attempting to retrieve h5_path from IPython store
# no stored variable or alias h5_path
# [13:58:14.952] [H5] h5_path not found in IPython store
# [13:58:14.953] [GUI] Created file upload widget
# [13:58:14.954] [GUI] Created energy conversion widgets
# [13:58:14.956] [GUI] Created time control widgets
# [13:58:14.958] [GUI] Created peak detection widgets
# [13:58:14.959] [GUI] Created peak model widgets
# [13:58:14.960] [GUI] Created wavelength range widgets
# [13:58:14.967] [GUI] Created background handling widgets
# [13:58:14.969] [GUI] Created fitting action widgets
# [13:58:14.971] [GUI] Created batch fitting widgets
# [13:58:14.971] [GUI] Created export widgets
# [13:58:14.972] [GUI] Created output widgets
# [13:58:14.973] [GUI] Created unit conversion widgets
# [13:58:14.973] [GUI] Created all GUI widgets
# [13:58:14.973] [APP] Setting up UI callbacks
# ...
