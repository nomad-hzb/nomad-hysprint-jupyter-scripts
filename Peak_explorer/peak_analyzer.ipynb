# %% [markdown]
# # Peak Analyzer
#
# Interactive application for analyzing spectral and diffraction data with peak detection and fitting.

# %%
from gui_layouts import PLAnalysisApp

app = PLAnalysisApp()
app.display_app()
# Out:
# [10:01:49.336] [APP] Initializing PLAnalysisApp
# [10:01:49.336] [H5] Attempting to retrieve h5_path from IPython store
# no stored variable or alias h5_path
# [10:01:49.336] [H5] h5_path not found in IPython store
# [10:01:49.337] [GUI] Created file upload widget
# [10:01:49.338] [GUI] Created energy conversion widgets
# [10:01:49.340] [GUI] Created time control widgets
# [10:01:49.342] [GUI] Created peak detection widgets
# [10:01:49.343] [GUI] Created peak model widgets
# [10:01:49.344] [GUI] Created wavelength range widgets
# [10:01:49.351] [GUI] Created background handling widgets
# [10:01:49.352] [GUI] Created fitting action widgets
# [10:01:49.354] [GUI] Created batch fitting widgets
# [10:01:49.355] [GUI] Created export widgets
# [10:01:49.356] [GUI] Created output widgets
# [10:01:49.356] [GUI] Created unit conversion widgets
# [10:01:49.356] [GUI] Created all GUI widgets
# [10:01:49.356] [APP] Setting up UI callbacks
# [10:01:49.357] [APP] Background method changed to: None
# [10:01:49.357] [APP] Adding peak model 0
# [10:01:49.360] [GUI] Peak 0 type changed to Gaussian
# [10:01:49.362] [APP] Wavelength range callback connected to FloatRangeSlider(value=(400.0, 800.0), continuous_update=False, description='λ Range (nm):', disabled=True, layout=Layout(width='400px'), max=1000.0, min=300.0, readout_format='.3f', step=0.001, style=SliderStyle(description_width='initial'))
# [10:01:49.362] [APP] Connected unit conversion callbacks
# [10:01:49.362] [APP] Callbacks setup complete
# [10:01:49.362] [APP] Displaying application
# [10:01:49.364] [GUI] Created file section layout
# [10:01:49.365] [GUI] Created time control section layout
# [10:01:49.366] [GUI] Created unit conversion section layout
# [10:01:49.369] [GUI] Created background section layout
# [10:01:49.371] [GUI] Created peak detection section layout
# [10:01:49.372] [GUI] Created fitting actions section layout
# [10:01:49.374] [GUI] Created batch fitting section layout
# [10:01:49.375] [GUI] Created fitting control section layout
# [10:01:49.375] [GUI] Created control panel layout
# [10:01:49.377] [GUI] Created visualization section layout
# [10:01:49.377] [GUI] Created main layout
# [10:01:49.377] [APP] Stored background accordion reference
# HTML(value='<h1>🔬 Peak Analysis App</h1>')
# HBox(children=(VBox(children=(HTML(value='<h3>📋 Status</h3>'), Output(), HTML(value='<hr>'), VBox(children=(HT…
# [10:01:49.388] [APP] Application displayed
