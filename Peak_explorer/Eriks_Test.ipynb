# %%
import os 
import contextlib
import io

local_h5_path = r"G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5"

def store_var(var):
    with contextlib.redirect_stdout(io.StringIO()):
        from IPython import get_ipython
        ip = get_ipython()
        ip.run_line_magic("store", var)

ip = get_ipython()

base = os.getcwd()
rel = local_h5_path
result = os.path.normpath(os.path.join(base, rel))

ip.user_ns["h5_path"] = result
store_var("h5_path")

# %%
from gui_layouts import PLAnalysisApp

app = PLAnalysisApp()
app.display_app()
# Out:
# ✅ ipyvuetify FileInput initialized
# [19:57:50.438] [APP] Initializing PLAnalysisApp
# [19:57:50.438] [H5] Attempting to retrieve h5_path from IPython store
# [19:57:50.442] [H5] Found h5_path: G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5
# [19:57:50.443] [APP] PlotManager app_ref set
# [19:57:50.451] [GUI] Created H5 mode dropdown
# [19:57:50.457] [GUI] Created energy conversion widgets
# [19:57:50.463] [GUI] Created time control widgets
# [19:57:50.467] [GUI] Created peak detection widgets
# [19:57:50.470] [GUI] Created peak model widgets
# [19:57:50.471] [GUI] Created wavelength range widgets
# [19:57:50.485] [GUI] Created background handling widgets
# [19:57:50.487] [GUI] Created fitting action widgets
# [19:57:50.493] [GUI] Created batch fitting widgets
# [19:57:50.494] [GUI] Created export widgets
# [19:57:50.495] [GUI] Created output widgets
# [19:57:50.497] [GUI] Created unit conversion widgets
# [19:57:50.499] [GUI] Created colorbar widgets
# [19:57:50.499] [GUI] Created all GUI widgets
# [19:57:50.499] [APP] Setting up UI callbacks
# [19:57:50.499] [APP] Background method changed to: None
# [19:57:50.499] [APP] Adding peak model 0
# [19:57:50.517] [GUI] Peak 0 type changed to Gaussian
# [19:57:50.519] [APP] Wavelength range callback connected to FloatRangeSlider(value=(400.0, 800.0), continuous_update=False, description='λ Range (nm):', disabled=True, layout=Layout(width='400px'), max=1000.0, min=300.0, readout_format='.3f', step=0.001, style=SliderStyle(description_width='initial'))
# [19:57:50.519] [APP] Connected unit conversion callbacks
# [19:57:50.519] [APP] Callbacks setup complete
# [19:57:50.519] [APP] H5 data available, triggering initial load
# [19:57:50.519] [APP] !!! CALLBACK TRIGGERED !!!
# [19:57:50.521] [APP] ==================================================
# [19:57:50.521] [APP] File upload triggered
# [19:57:50.529] [DATA] Loading data from H5 (mode: giwaxs)
# [19:57:50.628] [H5] Loading H5 data in mode: giwaxs
# [19:57:50.632] [H5] Removing NaN from last timestamp entry
# [19:57:50.632] [H5] Loaded H5 data: (222, 1000), 1000 wavelengths, 222 times
# [19:57:50.632] [H5] Wavelength range: 0.00 - 0.28 nm
# [19:57:50.632] [H5] Timestamp range: -19.98 - 318.02 s
# [19:57:50.632] [DATA] H5 data loaded successfully: (222, 1000)
# [19:57:50.632] [update_ui_after_data_load] Updating UI after data load
# [19:57:50.632] [update_ui_after_data_load] Time range indices: min=0, max=221
# [19:57:50.633] [update_ui_after_data_load] Wavelength range: min=0.0001401128867965468, max=0.28008566070629703
# [19:57:50.633] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (0.28008566070629703, 0.28008566070629703) =====
# [19:57:50.633] [DEBUG] Data is loaded, proceeding...
# [19:57:50.633] [DEBUG] wl_min=0.0001401128867965468, wl_max=0.28008566070629703, range=(0.28008566070629703, 0.28008566070629703)
# [19:57:50.634] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [19:57:50.634] [SPECTRUM] Updating spectrum range to (0.28008566070629703, 0.28008566070629703)
# [19:57:50.634] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x000001B379228C80>
# [19:57:50.634] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [19:57:50.634] [SPECTRUM] spectrum_fig is None? True
# [19:57:50.634] [SPECTRUM] No range or no spectrum fig, returning early
# [19:57:50.634] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [19:57:50.634] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [19:57:50.634] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [19:57:50.634] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (0.0001401128867965468, 0.28008566070629703) =====
# [19:57:50.634] [DEBUG] Data is loaded, proceeding...
# [19:57:50.634] [DEBUG] wl_min=0.0001401128867965468, wl_max=0.28008566070629703, range=(0.0001401128867965468, 0.28008566070629703)
# [19:57:50.634] [DEBUG] Range is at borders, setting to None
# [19:57:50.634] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [19:57:50.634] [SPECTRUM] Updating spectrum range to None
# [19:57:50.634] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x000001B379228C80>
# [19:57:50.634] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [19:57:50.634] [SPECTRUM] spectrum_fig is None? True
# [19:57:50.634] [SPECTRUM] No range or no spectrum fig, returning early
# [19:57:50.634] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [19:57:50.634] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [19:57:50.634] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [19:57:50.635] [APP] No heatmap to update
# [19:57:50.640] [APP] No heatmap to update
# [19:57:50.645] [update_ui_after_data_load] UI updated after data load
# [19:57:50.645] [APP] Updating visualizations
# [19:57:53.923] [APP] Displaying application
# [19:57:53.926] [GUI] Created file section layout
# [19:57:53.928] [GUI] Created time control section layout
# [19:57:53.929] [GUI] Created colorbar section layout
# [19:57:53.935] [GUI] Created background section layout
# [19:57:53.942] [GUI] Created peak detection section layout
# [19:57:53.944] [GUI] Created fitting actions section layout
# [19:57:53.949] [GUI] Created batch fitting section layout
# [19:57:53.950] [GUI] Created fitting control section layout
# [19:57:53.950] [GUI] Created control panel layout
# [19:57:53.954] [GUI] Created visualization section layout
# [19:57:53.954] [GUI] Created main layout
# [19:57:53.954] [APP] Stored background accordion reference
# HTML(value='<h1>🔬 Peak Analysis App</h1>')
# HBox(children=(VBox(children=(HTML(value='<h3>📋 Status</h3>'), Output(), HTML(value='<hr>'), VBox(children=(HT…
# [19:57:53.967] [APP] Application displayed
