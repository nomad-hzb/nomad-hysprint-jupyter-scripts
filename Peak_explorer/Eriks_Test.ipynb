# %%
import os 
import contextlib
import io

local_h5_path = r"G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5"

def store_var(var):
    with contextlib.redirect_stdout(io.StringIO()):
        from IPython import get_ipython
        ip = get_ipython()
        ip.run_line_magic("store", var)

ip = get_ipython()

base = os.getcwd()
rel = local_h5_path
result = os.path.normpath(os.path.join(base, rel))

ip.user_ns["h5_path"] = result
store_var("h5_path")

# %%
from gui_layouts import PLAnalysisApp

app = PLAnalysisApp()
app.display_app()
# Out:
# ✅ ipyvuetify FileInput initialized
# [19:22:59.545] [APP] Initializing PLAnalysisApp
# [19:22:59.545] [H5] Attempting to retrieve h5_path from IPython store
# [19:22:59.546] [H5] Found h5_path: G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5
# [19:22:59.546] [APP] PlotManager app_ref set
# [19:22:59.548] [GUI] Created H5 mode dropdown
# [19:22:59.549] [GUI] Created energy conversion widgets
# [19:22:59.551] [GUI] Created time control widgets
# [19:22:59.553] [GUI] Created peak detection widgets
# [19:22:59.554] [GUI] Created peak model widgets
# [19:22:59.555] [GUI] Created wavelength range widgets
# [19:22:59.566] [GUI] Created background handling widgets
# [19:22:59.568] [GUI] Created fitting action widgets
# [19:22:59.573] [GUI] Created batch fitting widgets
# [19:22:59.575] [GUI] Created export widgets
# [19:22:59.579] [GUI] Created output widgets
# [19:22:59.583] [GUI] Created unit conversion widgets
# [19:22:59.584] [GUI] Created colorbar widgets
# [19:22:59.584] [GUI] Created all GUI widgets
# [19:22:59.584] [APP] Setting up UI callbacks
# [19:22:59.584] [APP] Background method changed to: None
# [19:22:59.584] [APP] Adding peak model 0
# [19:22:59.605] [GUI] Peak 0 type changed to Gaussian
# [19:22:59.607] [APP] Wavelength range callback connected to FloatRangeSlider(value=(400.0, 800.0), continuous_update=False, description='λ Range (nm):', disabled=True, layout=Layout(width='400px'), max=1000.0, min=300.0, readout_format='.3f', step=0.001, style=SliderStyle(description_width='initial'))
# [19:22:59.607] [APP] Connected unit conversion callbacks
# [19:22:59.607] [APP] Callbacks setup complete
# [19:22:59.607] [APP] H5 data available, triggering initial load
# [19:22:59.607] [APP] !!! CALLBACK TRIGGERED !!!
# [19:22:59.609] [APP] ==================================================
# [19:22:59.609] [APP] File upload triggered
# [19:22:59.618] [DATA] Loading data from H5 (mode: giwaxs)
# [19:22:59.759] [H5] Loading H5 data in mode: giwaxs
# [19:22:59.764] [H5] Removing NaN from last timestamp entry
# [19:22:59.764] [H5] Loaded H5 data: (222, 1000), 1000 wavelengths, 222 times
# [19:22:59.764] [H5] Wavelength range: 0.00 - 0.28 nm
# [19:22:59.764] [H5] Timestamp range: -19.98 - 318.02 s
# [19:22:59.764] [DATA] H5 data loaded successfully: (222, 1000)
# [19:22:59.764] [update_ui_after_data_load] Updating UI after data load
# [19:22:59.764] [update_ui_after_data_load] Time range indices: min=0, max=221
# [19:22:59.766] [update_ui_after_data_load] Wavelength range: min=0.0001401128867965468, max=0.28008566070629703
# [19:22:59.766] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (0.28008566070629703, 0.28008566070629703) =====
# [19:22:59.766] [DEBUG] Data is loaded, proceeding...
# [19:22:59.766] [DEBUG] wl_min=0.0001401128867965468, wl_max=0.28008566070629703, range=(0.28008566070629703, 0.28008566070629703)
# [19:22:59.767] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [19:22:59.767] [SPECTRUM] Updating spectrum range to (0.28008566070629703, 0.28008566070629703)
# [19:22:59.767] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x000001A2FE556900>
# [19:22:59.767] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [19:22:59.767] [SPECTRUM] spectrum_fig is None? True
# [19:22:59.767] [SPECTRUM] No range or no spectrum fig, returning early
# [19:22:59.767] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [19:22:59.767] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [19:22:59.767] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [19:22:59.768] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (0.0001401128867965468, 0.28008566070629703) =====
# [19:22:59.768] [DEBUG] Data is loaded, proceeding...
# [19:22:59.768] [DEBUG] wl_min=0.0001401128867965468, wl_max=0.28008566070629703, range=(0.0001401128867965468, 0.28008566070629703)
# [19:22:59.769] [DEBUG] Range is at borders, setting to None
# [19:22:59.769] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [19:22:59.769] [SPECTRUM] Updating spectrum range to None
# [19:22:59.769] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x000001A2FE556900>
# [19:22:59.769] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [19:22:59.769] [SPECTRUM] spectrum_fig is None? True
# [19:22:59.769] [SPECTRUM] No range or no spectrum fig, returning early
# [19:22:59.769] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [19:22:59.769] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [19:22:59.769] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [19:22:59.772] [APP] No heatmap to update
# [19:22:59.781] [APP] No heatmap to update
# [19:22:59.789] [update_ui_after_data_load] UI updated after data load
# [19:22:59.789] [APP] Updating visualizations
# [19:23:03.425] [APP] Displaying application
# [19:23:03.438] [GUI] Created file section layout
# [19:23:03.443] [GUI] Created time control section layout
# [19:23:03.446] [GUI] Created colorbar section layout
# [19:23:03.471] [GUI] Created background section layout
# [19:23:03.493] [GUI] Created peak detection section layout
# [19:23:03.497] [GUI] Created fitting actions section layout
# [19:23:03.506] [GUI] Created batch fitting section layout
# [19:23:03.507] [GUI] Created fitting control section layout
# [19:23:03.508] [GUI] Created control panel layout
# [19:23:03.512] [GUI] Created visualization section layout
# [19:23:03.514] [GUI] Created main layout
# [19:23:03.514] [APP] Stored background accordion reference
# HTML(value='<h1>🔬 Peak Analysis App</h1>')
# HBox(children=(VBox(children=(HTML(value='<h3>📋 Status</h3>'), Output(), HTML(value='<hr>'), VBox(children=(HT…
# [19:23:03.536] [APP] Application displayed
