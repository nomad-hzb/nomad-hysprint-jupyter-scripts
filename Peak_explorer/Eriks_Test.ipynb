# %%
import os 
import contextlib
import io

local_h5_path = r"G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5"

def store_var(var):
    with contextlib.redirect_stdout(io.StringIO()):
        from IPython import get_ipython
        ip = get_ipython()
        ip.run_line_magic("store", var)

ip = get_ipython()

base = os.getcwd()
rel = local_h5_path
result = os.path.normpath(os.path.join(base, rel))

ip.user_ns["h5_path"] = result
store_var("h5_path")

# %%
from gui_layouts import PLAnalysisApp

app = PLAnalysisApp()
app.display_app()
# Out:
# ✅ ipyvuetify FileInput initialized
# [17:54:37.260] [APP] Initializing PLAnalysisApp
# [17:54:37.260] [H5] Attempting to retrieve h5_path from IPython store
# [17:54:37.261] [H5] Found h5_path: G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5
# [17:54:37.261] [APP] PlotManager app_ref set
# [17:54:37.262] [GUI] Created H5 mode dropdown
# [17:54:37.264] [GUI] Created energy conversion widgets
# [17:54:37.267] [GUI] Created time control widgets
# [17:54:37.271] [GUI] Created peak detection widgets
# [17:54:37.273] [GUI] Created peak model widgets
# [17:54:37.274] [GUI] Created wavelength range widgets
# [17:54:37.289] [GUI] Created background handling widgets
# [17:54:37.292] [GUI] Created fitting action widgets
# [17:54:37.295] [GUI] Created batch fitting widgets
# [17:54:37.298] [GUI] Created export widgets
# [17:54:37.299] [GUI] Created output widgets
# [17:54:37.302] [GUI] Created unit conversion widgets
# [17:54:37.303] [GUI] Created colorbar widgets
# [17:54:37.303] [GUI] Created all GUI widgets
# [17:54:37.303] [APP] Setting up UI callbacks
# [17:54:37.303] [APP] Background method changed to: None
# [17:54:37.304] [APP] Adding peak model 0
# [17:54:37.325] [GUI] Peak 0 type changed to Gaussian
# [17:54:37.329] [APP] Wavelength range callback connected to FloatRangeSlider(value=(400.0, 800.0), continuous_update=False, description='λ Range (nm):', disabled=True, layout=Layout(width='400px'), max=1000.0, min=300.0, readout_format='.3f', step=0.001, style=SliderStyle(description_width='initial'))
# [17:54:37.329] [APP] Connected unit conversion callbacks
# [17:54:37.329] [APP] Callbacks setup complete
# [17:54:37.329] [APP] H5 data available, triggering initial load
# [17:54:37.329] [APP] !!! CALLBACK TRIGGERED !!!
# [17:54:37.338] [APP] ==================================================
# [17:54:37.338] [APP] File upload triggered
# [17:54:37.346] [DATA] Loading data from H5 (mode: giwaxs)
# [17:54:37.677] [H5] Loading H5 data in mode: giwaxs
# [17:54:37.685] [H5] Removing NaN from last timestamp entry
# [17:54:37.685] [H5] Loaded H5 data: (222, 1000), 1000 wavelengths, 222 times
# [17:54:37.685] [H5] Wavelength range: 0.00 - 0.28 nm
# [17:54:37.685] [H5] Timestamp range: -19.98 - 318.02 s
# [17:54:37.685] [DATA] H5 data loaded successfully: (222, 1000)
# [17:54:37.685] [update_ui_after_data_load] Updating UI after data load
# [17:54:37.685] [update_ui_after_data_load] Time range indices: min=0, max=221
# [17:54:37.687] [update_ui_after_data_load] Wavelength range: min=0.0001401128867965468, max=0.28008566070629703
# [17:54:37.687] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (0.28008566070629703, 0.28008566070629703) =====
# [17:54:37.687] [DEBUG] Data is loaded, proceeding...
# [17:54:37.688] [DEBUG] wl_min=0.0001401128867965468, wl_max=0.28008566070629703, range=(0.28008566070629703, 0.28008566070629703)
# [17:54:37.688] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [17:54:37.688] [SPECTRUM] Updating spectrum range to (0.28008566070629703, 0.28008566070629703)
# [17:54:37.688] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x00000186BE6D26C0>
# [17:54:37.688] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [17:54:37.688] [SPECTRUM] spectrum_fig is None? True
# [17:54:37.688] [SPECTRUM] No range or no spectrum fig, returning early
# [17:54:37.688] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [17:54:37.688] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [17:54:37.688] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [17:54:37.689] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (0.0001401128867965468, 0.28008566070629703) =====
# [17:54:37.689] [DEBUG] Data is loaded, proceeding...
# [17:54:37.689] [DEBUG] wl_min=0.0001401128867965468, wl_max=0.28008566070629703, range=(0.0001401128867965468, 0.28008566070629703)
# [17:54:37.689] [DEBUG] Range is at borders, setting to None
# [17:54:37.689] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [17:54:37.689] [SPECTRUM] Updating spectrum range to None
# [17:54:37.689] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x00000186BE6D26C0>
# [17:54:37.689] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [17:54:37.689] [SPECTRUM] spectrum_fig is None? True
# [17:54:37.689] [SPECTRUM] No range or no spectrum fig, returning early
# [17:54:37.689] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [17:54:37.689] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [17:54:37.689] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [17:54:37.689] [update_ui_after_data_load] Wavelength range slider enabled
# [17:54:37.691] [APP] No heatmap to update
# [17:54:37.700] [APP] No heatmap to update
# [17:54:37.708] [update_ui_after_data_load] UI updated after data load
# [17:54:37.708] [APP] Updating visualizations
# [17:54:43.733] [APP] Displaying application
# [17:54:43.737] [GUI] Created file section layout
# [17:54:43.739] [GUI] Created time control section layout
# [17:54:43.741] [GUI] Created colorbar section layout
# [17:54:43.747] [GUI] Created background section layout
# [17:54:43.754] [GUI] Created peak detection section layout
# [17:54:43.756] [GUI] Created fitting actions section layout
# [17:54:43.760] [GUI] Created batch fitting section layout
# [17:54:43.761] [GUI] Created fitting control section layout
# [17:54:43.761] [GUI] Created control panel layout
# [17:54:43.765] [GUI] Created visualization section layout
# [17:54:43.765] [GUI] Created main layout
# [17:54:43.766] [APP] Stored background accordion reference
# HTML(value='<h1>🔬 Peak Analysis App</h1>')
# HBox(children=(VBox(children=(HTML(value='<h3>📋 Status</h3>'), Output(), HTML(value='<hr>'), VBox(children=(HT…
# [17:54:43.780] [APP] Application displayed
