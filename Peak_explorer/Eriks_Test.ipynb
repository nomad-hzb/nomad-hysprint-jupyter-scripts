# %%
import os 
import contextlib
import io

local_h5_path = r"G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5"

def store_var(var):
    with contextlib.redirect_stdout(io.StringIO()):
        from IPython import get_ipython
        ip = get_ipython()
        ip.run_line_magic("store", var)

ip = get_ipython()

base = os.getcwd()
rel = local_h5_path
result = os.path.normpath(os.path.join(base, rel))

ip.user_ns["h5_path"] = result
store_var("h5_path")

# %%
from gui_layouts import PLAnalysisApp

app = PLAnalysisApp()
app.display_app()
# Out:
# ✅ ipyvuetify FileInput initialized
# [18:22:23.038] [APP] Initializing PLAnalysisApp
# [18:22:23.038] [H5] Attempting to retrieve h5_path from IPython store
# [18:22:23.039] [H5] Found h5_path: G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5
# [18:22:23.039] [APP] PlotManager app_ref set
# [18:22:23.042] [GUI] Created H5 mode dropdown
# [18:22:23.045] [GUI] Created energy conversion widgets
# [18:22:23.050] [GUI] Created time control widgets
# [18:22:23.059] [GUI] Created peak detection widgets
# [18:22:23.063] [GUI] Created peak model widgets
# [18:22:23.064] [GUI] Created wavelength range widgets
# [18:22:23.102] [GUI] Created background handling widgets
# [18:22:23.110] [GUI] Created fitting action widgets
# [18:22:23.115] [GUI] Created batch fitting widgets
# [18:22:23.116] [GUI] Created export widgets
# [18:22:23.120] [GUI] Created output widgets
# [18:22:23.121] [GUI] Created unit conversion widgets
# [18:22:23.124] [GUI] Created colorbar widgets
# [18:22:23.124] [GUI] Created all GUI widgets
# [18:22:23.124] [APP] Setting up UI callbacks
# [18:22:23.124] [APP] Background method changed to: None
# [18:22:23.124] [APP] Adding peak model 0
# [18:22:23.143] [GUI] Peak 0 type changed to Gaussian
# [18:22:23.146] [APP] Wavelength range callback connected to FloatRangeSlider(value=(400.0, 800.0), continuous_update=False, description='λ Range (nm):', disabled=True, layout=Layout(width='400px'), max=1000.0, min=300.0, readout_format='.3f', step=0.001, style=SliderStyle(description_width='initial'))
# [18:22:23.146] [APP] Connected unit conversion callbacks
# [18:22:23.146] [APP] Callbacks setup complete
# [18:22:23.146] [APP] H5 data available, triggering initial load
# [18:22:23.146] [APP] !!! CALLBACK TRIGGERED !!!
# [18:22:23.153] [APP] ==================================================
# [18:22:23.153] [APP] File upload triggered
# [18:22:23.163] [DATA] Loading data from H5 (mode: giwaxs)
# [18:22:23.279] [H5] Loading H5 data in mode: giwaxs
# [18:22:23.283] [H5] Removing NaN from last timestamp entry
# [18:22:23.283] [H5] Loaded H5 data: (222, 1000), 1000 wavelengths, 222 times
# [18:22:23.283] [H5] Wavelength range: 0.00 - 0.28 nm
# [18:22:23.283] [H5] Timestamp range: -19.98 - 318.02 s
# [18:22:23.283] [DATA] H5 data loaded successfully: (222, 1000)
# [18:22:23.283] [update_ui_after_data_load] Updating UI after data load
# [18:22:23.283] [update_ui_after_data_load] Time range indices: min=0, max=221
# [18:22:23.285] [update_ui_after_data_load] Wavelength range: min=0.0001401128867965468, max=0.28008566070629703
# [18:22:23.286] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (0.28008566070629703, 0.28008566070629703) =====
# [18:22:23.286] [DEBUG] Data is loaded, proceeding...
# [18:22:23.286] [DEBUG] wl_min=0.0001401128867965468, wl_max=0.28008566070629703, range=(0.28008566070629703, 0.28008566070629703)
# [18:22:23.286] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [18:22:23.286] [SPECTRUM] Updating spectrum range to (0.28008566070629703, 0.28008566070629703)
# [18:22:23.286] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x0000020CFFDF79E0>
# [18:22:23.286] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [18:22:23.286] [SPECTRUM] spectrum_fig is None? True
# [18:22:23.286] [SPECTRUM] No range or no spectrum fig, returning early
# [18:22:23.286] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [18:22:23.286] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [18:22:23.286] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [18:22:23.286] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (0.0001401128867965468, 0.28008566070629703) =====
# [18:22:23.286] [DEBUG] Data is loaded, proceeding...
# [18:22:23.286] [DEBUG] wl_min=0.0001401128867965468, wl_max=0.28008566070629703, range=(0.0001401128867965468, 0.28008566070629703)
# [18:22:23.286] [DEBUG] Range is at borders, setting to None
# [18:22:23.286] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [18:22:23.286] [SPECTRUM] Updating spectrum range to None
# [18:22:23.286] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x0000020CFFDF79E0>
# [18:22:23.286] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [18:22:23.286] [SPECTRUM] spectrum_fig is None? True
# [18:22:23.286] [SPECTRUM] No range or no spectrum fig, returning early
# [18:22:23.286] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [18:22:23.286] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [18:22:23.286] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [18:22:23.287] [APP] No heatmap to update
# [18:22:23.293] [APP] No heatmap to update
# [18:22:23.297] [update_ui_after_data_load] UI updated after data load
# [18:22:23.297] [APP] Updating visualizations
# [18:22:26.867] [APP] Displaying application
# [18:22:26.869] [GUI] Created file section layout
# [18:22:26.871] [GUI] Created time control section layout
# [18:22:26.872] [GUI] Created colorbar section layout
# [18:22:26.879] [GUI] Created background section layout
# [18:22:26.886] [GUI] Created peak detection section layout
# [18:22:26.887] [GUI] Created fitting actions section layout
# [18:22:26.891] [GUI] Created batch fitting section layout
# [18:22:26.892] [GUI] Created fitting control section layout
# [18:22:26.892] [GUI] Created control panel layout
# [18:22:26.896] [GUI] Created visualization section layout
# [18:22:26.896] [GUI] Created main layout
# [18:22:26.896] [APP] Stored background accordion reference
# HTML(value='<h1>🔬 Peak Analysis App</h1>')
# HBox(children=(VBox(children=(HTML(value='<h3>📋 Status</h3>'), Output(), HTML(value='<hr>'), VBox(children=(HT…
# [18:22:26.912] [APP] Application displayed
