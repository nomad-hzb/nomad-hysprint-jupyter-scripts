# %%
import os 
import contextlib
import io

local_h5_path = r"G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5"

def store_var(var):
    with contextlib.redirect_stdout(io.StringIO()):
        from IPython import get_ipython
        ip = get_ipython()
        ip.run_line_magic("store", var)

ip = get_ipython()

base = os.getcwd()
rel = local_h5_path
result = os.path.normpath(os.path.join(base, rel))

ip.user_ns["h5_path"] = result
store_var("h5_path")

# %%
from gui_layouts import PLAnalysisApp

app = PLAnalysisApp()
app.display_app()
# Out:
# ✅ ipyvuetify FileInput initialized
# [19:46:31.882] [APP] Initializing PLAnalysisApp
# [19:46:31.882] [H5] Attempting to retrieve h5_path from IPython store
# [19:46:31.884] [H5] Found h5_path: G:\Data_for_NOMAD\2025_03_MySpot\Lennart_Last_Day\beamtime_2025-02-25_experiment_1248.h5
# [19:46:31.884] [APP] PlotManager app_ref set
# [19:46:31.888] [GUI] Created H5 mode dropdown
# [19:46:31.895] [GUI] Created energy conversion widgets
# [19:46:31.900] [GUI] Created time control widgets
# [19:46:31.909] [GUI] Created peak detection widgets
# [19:46:31.911] [GUI] Created peak model widgets
# [19:46:31.913] [GUI] Created wavelength range widgets
# [19:46:31.947] [GUI] Created background handling widgets
# [19:46:31.951] [GUI] Created fitting action widgets
# [19:46:31.957] [GUI] Created batch fitting widgets
# [19:46:31.958] [GUI] Created export widgets
# [19:46:31.960] [GUI] Created output widgets
# [19:46:31.961] [GUI] Created unit conversion widgets
# [19:46:31.963] [GUI] Created colorbar widgets
# [19:46:31.963] [GUI] Created all GUI widgets
# [19:46:31.963] [APP] Setting up UI callbacks
# [19:46:31.963] [APP] Background method changed to: None
# [19:46:31.963] [APP] Adding peak model 0
# [19:46:31.981] [GUI] Peak 0 type changed to Gaussian
# [19:46:31.983] [APP] Wavelength range callback connected to FloatRangeSlider(value=(400.0, 800.0), continuous_update=False, description='λ Range (nm):', disabled=True, layout=Layout(width='400px'), max=1000.0, min=300.0, readout_format='.3f', step=0.001, style=SliderStyle(description_width='initial'))
# [19:46:31.983] [APP] Connected unit conversion callbacks
# [19:46:31.983] [APP] Callbacks setup complete
# [19:46:31.983] [APP] H5 data available, triggering initial load
# [19:46:31.983] [APP] !!! CALLBACK TRIGGERED !!!
# [19:46:31.986] [APP] ==================================================
# [19:46:31.986] [APP] File upload triggered
# [19:46:31.997] [DATA] Loading data from H5 (mode: giwaxs)
# [19:46:32.107] [H5] Loading H5 data in mode: pl_binned
# [19:46:32.123] [H5] Calculating axes from extent
# [19:46:32.124] [H5] Loaded H5 data: (3000, 1500), 1500 wavelengths, 3000 times
# [19:46:32.124] [H5] Wavelength range: 296.54 - 1082.25 nm
# [19:46:32.124] [H5] Timestamp range: -25.21 - 337.03 s
# [19:46:32.124] [DATA] H5 data loaded successfully: (3000, 1500)
# [19:46:32.124] [update_ui_after_data_load] Updating UI after data load
# [19:46:32.124] [update_ui_after_data_load] Time range indices: min=0, max=2999
# [19:46:32.126] [update_ui_after_data_load] Wavelength range: min=296.53558349609375, max=1082.2549633942976
# [19:46:32.126] [DEBUG] ===== WAVELENGTH RANGE CALLBACK TRIGGERED: (296.53558349609375, 1082.2549633942976) =====
# [19:46:32.126] [DEBUG] Data is loaded, proceeding...
# [19:46:32.126] [DEBUG] wl_min=296.53558349609375, wl_max=1082.2549633942976, range=(296.53558349609375, 1082.2549633942976)
# [19:46:32.126] [DEBUG] Range is at borders, setting to None
# [19:46:32.126] [DEBUG] About to call _update_wavelength_range_on_spectrum
# [19:46:32.126] [SPECTRUM] Updating spectrum range to None
# [19:46:32.127] [SPECTRUM] self.plot_manager = <plot_manager.PlotManager object at 0x00000205F570D5B0>
# [19:46:32.127] [SPECTRUM] self.plot_manager.spectrum_fig = None
# [19:46:32.127] [SPECTRUM] spectrum_fig is None? True
# [19:46:32.127] [SPECTRUM] No range or no spectrum fig, returning early
# [19:46:32.127] [DEBUG] Finished _update_wavelength_range_on_spectrum
# [19:46:32.127] [DEBUG] About to call _update_wavelength_range_on_heatmap
# [19:46:32.127] [DEBUG] Finished _update_wavelength_range_on_heatmap
# [19:46:32.133] [APP] No heatmap to update
# [19:46:32.138] [update_ui_after_data_load] UI updated after data load
# [19:46:32.138] [APP] Updating visualizations
