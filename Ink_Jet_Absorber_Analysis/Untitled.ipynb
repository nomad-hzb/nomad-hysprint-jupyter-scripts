# %%
import requests
url_base ="https://nomad-hzb-se.de"
url = f"{url_base}/nomad-oasis/api/v1"

response = requests.post(
                f'{url}/auth/token',
                data=dict(grant_type="password",username="michael.goette@helmholtz-berlin.de", password="Nomad009!")
            )
response.json()
# Out:
# {'access_token': 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJmb1hmZnM5QlFQWHduLU54Yk5PYlExOFhnZnlKU1FNRkl6ZFVnWjhrZzdVIn0.....GKFhrHsPsn-OTayVHl1JtaYFL5fBA9GCBbI6Tf5qpjtnLYouSX8CzHKZYQpTjycC09sdQgGCdHztFJ5BMP0OQBVlcYkKnlw1ICPzOOs3mAY3c3c_LD-56PhLAW703jDyJPr00RjXjDlTXUlya15S8BM94vVSnFjXryhfYbQbA5r71G-Tgur5FY8bO8uuAkSTUzZFZsNkkX_YGpssjvHgDxBRtiC1bYl-s1BAsvs4jDzgGpmCQTAq5Og8w2BuFXcvGUUzxz9RvkGgNjSq67FqQ4Vinv_HTtphYo2_NZnCNK9pT1lmlXqmuejvJP82_RBoksu0AEfmVIvb3aRIxH_8ig',
#  'token_type': 'bearer'}
